# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
#Read data
data = pd.read_excel('data.xlsx',sheet_name='PS19A_PERSON__SmplR10K')
#Shape the data
data.shape
# Out:
# (999, 31)

# %%
#Brief overview of 5 rows
data.head(1)
# Out:
#    person_id    person_name  \
# 0      89830  Hata, Yoshiki
#
#                                       person_address  \
# 0  c/o Hitachi Appliances, Inc. 390 Muramatsu, Sh...
#
#                                                 cln1  cln2  cln3  \
# 0  c/o Hitachi Appliances Inc. 390 Muramatsu Shim...   NaN   NaN
#
#   person_ctry_code  cnt  chr_len  chr_len_label  ...  street   nr  \
# 0               JP    1       90              1  ...     NaN  NaN
#
#            area    postal                       city     region  country  \
# 0  Shizuoka-ken  424-0926   Shizuoka-shi, Shimizu-ku  Muramatsu      NaN
#
#    unclear status label
# 0      NaN    NaN     0
#
# [1 rows x 31 columns]

# %%
#Fill all empty values with 0 for feature_columns
data['person_name'] = data['person_name'].fillna(0)
data['person_address'] = data['person_address'].fillna(0)
data['person_ctry_code'] = data['person_ctry_code'].fillna(0)

#Fill all empty values with 0 for predicted_columns
data['country'] = data['country'].fillna(0)
data['city'] = data['city'].fillna(0)
data['region'] = data['region'].fillna(0)
data['postal'] = data['postal'].fillna(0)
data['area'] = data['area'].fillna(0)
data['street'] = data['street'].fillna(0)
data['co'] = data['co'].fillna(0)
data['building'] = data['building'].fillna(0)
data['nr'] = data['nr'].fillna(0)

# %%
#Brief overview of first 5 rows
data.head(5)
# Out:
#    person_id                                       person_name  \
# 0      89830                                     Hata, Yoshiki
# 1     118819   Sakamura, Ken, Intellectual Property Department
# 2     227620        Takeda, Yuji Yokkaichi Plant of Mitsubishi
# 3     300146  INOUE, Mitsuo, MITSUBISHI DENKI KABUSHIKI KAISHA
# 4     433394                  The Engineering Business Limited
#
#                                       person_address  \
# 0  c/o Hitachi Appliances, Inc. 390 Muramatsu, Sh...
# 1  NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Naga...
# 2  Gas Chemical Company, Inc., 4-16-2, Hinagahiga...
# 3  2-3, Marunouchi 2-chome, Chiyoda-ku,Tokyo 100-...
# 4  Broomhaugh House Riding Mill,Northumberland NE...
#
#                                                 cln1  cln2  cln3  \
# 0  c/o Hitachi Appliances Inc. 390 Muramatsu Shim...   NaN   NaN
# 1  NTT DoCoMo Inc. Sanno Park Tower 11-1 Nagata- ...   NaN   NaN
# 2  Gas Chemical Company Inc. 4-16-2 Hinagahigashi...   NaN   NaN
# 3   2-3 Marunouchi 2-chome Chiyoda-ku Tokyo 100-8310   NaN   NaN
# 4  Broomhaugh House Riding Mill Northumberland NE...   NaN   NaN
#
#   person_ctry_code  cnt  chr_len  chr_len_label  ...  street   nr  \
# 0               JP    1       90              1  ...       0    0
# 1               JP    1       89              1  ...       0    0
# 2               JP    1       76              1  ...       0    0
# 3               JP    1       50              1  ...       0  2-3
# 4               GB    1       52              1  ...       0    0
#
#             area    postal                       city          region  \
# 0   Shizuoka-ken  424-0926   Shizuoka-shi, Shimizu-ku       Muramatsu
# 1        nagata-  100-6150                      Tokyo               0
# 2  Hinagahigashi         0              Yokkaichi-shi        510-0886
# 3     Chiyoda-ku  100-8310                      Tokyo               0
# 4              0  NE44 6EG                Riding Mill  Northumberland
#
#    country  unclear status label
# 0        0      NaN    NaN     0
# 1        0      NaN    NaN     0
# 2        0      NaN    NaN     0
# 3        0      NaN    NaN     0
# 4        0      NaN    NaN     0
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import LabelEnco
#  410 190 435 672 913   7 531 179 183 136 612 143 677  92  66 231 218 137
#  765 532 259 504 220 120 212 156 567   3 278  71 327 174 144 925 260 403
#  560  39   8 691 236  85  90  27  44 198 702  99  35 238 160 503 932  50
#  837  53  82  26 158 603 171 421 926 657 449 114 825 419 631 223 836  10
#  101 308 332 568 726 728 258 796 167 787 670 195  18 141 206 547 810 191
#  835 521 511 840 176  12 520  65 175 129 286 168 735  70 590 888 690 508
#  140 697  37 478 572 718 117 135 725 281 151 669 128 139 565 727 222 673
#  227 127 132 372 217 829 166 559  83 155 834 240 271 941  78 704  95  33
#   21  23  61  36  56 152 627  47  91 463  94 261  57 865 285 169 146  55
#   30 239 173 193  15 204 142 185 224 838  49 653  76 712 783  29 145 915
#  215 200 108 903 207 906 714 899 382 273 242  42 897 124 184 209 106 119
#  731 121 741 189 115 210 430 389 613 246 203  84 148 440 100 199 558 243
#  707 387  43 211 125 845  24 150 234 247 797 180 644 709 188 924 126 942
#   59 507 482 905 181 187 914  79  38  88 249 884 624 113 911  63   6 921
#  839 907 927  22 920 186 584 270 717 654 723 929 917 898 919 904 251 601
#  909  96 274 192 288 345  14 878 931 596 887 103 930 922 893 882 891 781
#  713 551 668  48 724 900  69 245 262 202 159 118 557 161 710 830 107 221
#  895 241 230 733 344 112 939 535 116 225 334 248 711  19 162 284 157  80
#  388 908 340 629  72 879 342 232  51 676 729 134 149 462 196 655  32 604
#  902 885 194  52  68  40 678 514 154 883 886 928 178 736 737 424 177 163
#  153 933 460  60 894 937 208 237 901 244 348  46 938 133 205 341 679 343
#  346  73 182 339 628 338 347  51 782]

# %%
from sklearn.preprocessing import LabelEncoder
l3 = LabelEncoder()
person_name = data.person_name.values
person_name = l3.fit_transform(person_name)

person_address = data["person_address"].values.astype(str)
person_address = l3.fit_transform(person_address)

person_ctry_code = data.person_ctry_code.values
person_ctry_code = l3.fit_transform(person_ctry_code)

#make the columns as string and encode it to a numeric

country = data.country.values.astype(str)
country = l3.fit_transform(country)

city = data.city.values.astype(str)
city = l3.fit_transform(city)

region = data.region.values.astype(str)
region = l3.fit_transform(region)

country = data.country.values.astype(str)
country = l3.fit_transform(country)

street = data.street.values.astype(str)
street = l3.fit_transform(street)

area = data.country.values.astype(str)
area = l3.fit_transform(area)

co = data.co.values.astype(str)
co = l3.fit_transform(co)

building = data.building.values.astype(str)
building = l3.fit_transform(building)

nr = data.nr.values.astype(str)
nr = l3.fit_transform(nr)

# %%
data['person_name'] = person_name
data['person_address'] = person_address
data['person_ctry_code'] = person_ctry_code

#Replace originalcolumns witht the numeric columns
data['city'] = city
data['country'] = country
data['region'] = region
data['postal'] = postal
data['area'] = area
data['street'] = street
data['co'] = co
data['building'] = building
data['nr'] = nr

# %%
#Brief overview of first 50
data.head(1)
# Out:
#    person_id  person_name  person_address  \
# 0      89830          302             896
#
#                                                 cln1  cln2  cln3  \
# 0  c/o Hitachi Appliances Inc. 390 Muramatsu Shim...   NaN   NaN
#
#    person_ctry_code  cnt  chr_len  chr_len_label  ...  street  nr  area  \
# 0                23    1       90              1  ...      18   3     1
#
#    postal  city  region  country  unclear status  label
# 0     151     1      91        1      NaN    NaN      0
#
# [1 rows x 31 columns]

# %%
#Detailed overview
data.describe()
# Out:
#           person_id  person_name  person_address  cln2  cln3  \
# count  9.990000e+02   999.000000      999.000000   0.0   0.0
# mean   2.070643e+07   499.000000      480.619620   NaN   NaN
# std    2.175683e+07   288.530761      271.033485   NaN   NaN
# min    3.540000e+03     0.000000        0.000000   NaN   NaN
# 25%    3.854371e+06   249.500000      248.500000   NaN   NaN
# 50%    9.143170e+06   499.000000      488.000000   NaN   NaN
# 75%    4.806491e+07   748.500000      718.500000   NaN   NaN
# max    6.971232e+07   998.000000      942.000000   NaN   NaN
#
#        person_ctry_code    cnt     chr_len  chr_len_label     nbr_tok  ...  \
# count        999.000000  999.0  999.000000          999.0  999.000000  ...
# mean          26.045045    1.0   32.092092            1.0    4.703704  ...
# std           13.166384    0.0   26.633592            0.0    3.758530  ...
# min            0.000000    1.0    2.000000            1.0    1.000000  ...
# 25%           14.000000    1.0   10.000000            1.0    1.000000  ...
# 50%           23.000000    1.0   29.000000            1.0    4.000000  ...
# 75%           41.000000    1.0   47.000000            1.0    7.000000  ...
# max           42.000000    1.0  164.000000            1.0   20.000000  ...
#
#          building      street          nr        area      postal        city  \
# count  999.000000  999.000000  999.000000  999.000000  999.000000  999.000000
# mean     8.287287  117.695696   49.288288    1.436436   92.729730  311.948949
# std     12.921086  140.093289   75.903938    2.545323  127.941906  221.292538
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      5.000000   18.000000    3.000000    1.000000    5.000000  100.500000
# 50%      5.000000   18.000000    3.000000    1.000000    5.000000  315.000000
# 75%      5.000000  216.500000   81.000000    1.000000  174.500000  519.500000
# max     85.000000  461.000000  266.000000   23.000000  418.000000  687.000000
#
#            region     country  status       label
# count  999.000000  999.000000     0.0  999.000000
# mean    31.118118    1.436436     NaN    0.470470
# std     46.385399    2.545323     NaN    0.499377
# min      0.000000    0.000000     NaN    0.000000
# 25%      3.000000    1.000000     NaN    0.000000
# 50%      3.000000    1.000000     NaN    0.000000
# 75%     48.000000    1.000000     NaN    1.000000
# max    165.000000   23.000000     NaN    1.000000
#
# [8 rows x 28 columns]

# %%
#renaming columns
from sklearn.model_selection import train_test_split
predicted_class = ['co', 'building', 'street','nr','area','postal','city','region','country']
feature_columns = ['person_name','person_address','person_ctry_code']

# %%
#renaming columns
X = data[feature_columns].values
Y = data[predicted_class].values


#renaming columns
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3) # 70% training and 30% test

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)

# %%
#from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
#print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
print(y_pred)
# Out:
# [[  1   5  18 ...   2   3   1]
#  [  1   5  18 ... 109   3   1]
#  [  1   5  53 ...  92   3   1]
#  ...
#  [  1   5  18 ...  90   3   1]
#  [  1   5  18 ...  63   3   1]
#  [  1   5  18 ...  86   3   1]]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-d8690d65fbc4> in <module>
# ----> 1 y_train_encoded = pred.apply(le.fit_transform)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'apply'
