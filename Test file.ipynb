# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
#Read data
data = pd.read_excel('data.xlsx',sheet_name='PS19A_PERSON__SmplR10K')

# %%
#Shape the data
data.shape
# Out:
# (999, 31)

# %%
#Brief overview of 5 rows
data.head(5)
# Out:
#    person_id                                       person_name  \
# 0      89830                                     Hata, Yoshiki
# 1     118819   Sakamura, Ken, Intellectual Property Department
# 2     227620        Takeda, Yuji Yokkaichi Plant of Mitsubishi
# 3     300146  INOUE, Mitsuo, MITSUBISHI DENKI KABUSHIKI KAISHA
# 4     433394                  The Engineering Business Limited
#
#                                       person_address  \
# 0  c/o Hitachi Appliances, Inc. 390 Muramatsu, Sh...
# 1  NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Naga...
# 2  Gas Chemical Company, Inc., 4-16-2, Hinagahiga...
# 3  2-3, Marunouchi 2-chome, Chiyoda-ku,Tokyo 100-...
# 4  Broomhaugh House Riding Mill,Northumberland NE...
#
#                                                 cln1  cln2  cln3  \
# 0  c/o Hitachi Appliances Inc. 390 Muramatsu Shim...   NaN   NaN
# 1  NTT DoCoMo Inc. Sanno Park Tower 11-1 Nagata- ...   NaN   NaN
# 2  Gas Chemical Company Inc. 4-16-2 Hinagahigashi...   NaN   NaN
# 3   2-3 Marunouchi 2-chome Chiyoda-ku Tokyo 100-8310   NaN   NaN
# 4  Broomhaugh House Riding Mill Northumberland NE...   NaN   NaN
#
#   person_ctry_code  cnt  chr_len  chr_len_label  ...  street   nr  \
# 0               JP    1       90              1  ...     NaN  NaN
# 1               JP    1       89              1  ...     NaN  NaN
# 2               JP    1       76              1  ...     NaN  NaN
# 3               JP    1       50              1  ...     NaN  2-3
# 4               GB    1       52              1  ...     NaN  NaN
#
#             area    postal                       city          region  \
# 0   Shizuoka-ken  424-0926   Shizuoka-shi, Shimizu-ku       Muramatsu
# 1        nagata-  100-6150                      Tokyo             NaN
# 2  Hinagahigashi       NaN              Yokkaichi-shi        510-0886
# 3     Chiyoda-ku  100-8310                      Tokyo             NaN
# 4            NaN  NE44 6EG                Riding Mill  Northumberland
#
#    country  unclear status label
# 0      NaN      NaN    NaN     0
# 1      NaN      NaN    NaN     0
# 2      NaN      NaN    NaN     0
# 3      NaN      NaN    NaN     0
# 4      NaN      NaN    NaN     0
#
# [5 rows x 31 columns]

# %%
#Fill all empty values with 0
data['country'] = data['country'].fillna(0)
data['city'] = data['city'].fillna(0)
data['region'] = data['region'].fillna(0)
data['postal'] = data['postal'].fillna(0)
data['area'] = data['area'].fillna(0)
data['street'] = data['street'].fillna(0)
data['co'] = data['co'].fillna(0)
data['building'] = data['building'].fillna(0)
data['nr'] = data['nr'].fillna(0)

# %%
#Brief overview of first 5 rows
data.head(5)
# Out:
#    person_id                                       person_name  \
# 0      89830                                     Hata, Yoshiki
# 1     118819   Sakamura, Ken, Intellectual Property Department
# 2     227620        Takeda, Yuji Yokkaichi Plant of Mitsubishi
# 3     300146  INOUE, Mitsuo, MITSUBISHI DENKI KABUSHIKI KAISHA
# 4     433394                  The Engineering Business Limited
#
#                                       person_address  \
# 0  c/o Hitachi Appliances, Inc. 390 Muramatsu, Sh...
# 1  NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Naga...
# 2  Gas Chemical Company, Inc., 4-16-2, Hinagahiga...
# 3  2-3, Marunouchi 2-chome, Chiyoda-ku,Tokyo 100-...
# 4  Broomhaugh House Riding Mill,Northumberland NE...
#
#                                                 cln1  cln2  cln3  \
# 0  c/o Hitachi Appliances Inc. 390 Muramatsu Shim...   NaN   NaN
# 1  NTT DoCoMo Inc. Sanno Park Tower 11-1 Nagata- ...   NaN   NaN
# 2  Gas Chemical Company Inc. 4-16-2 Hinagahigashi...   NaN   NaN
# 3   2-3 Marunouchi 2-chome Chiyoda-ku Tokyo 100-8310   NaN   NaN
# 4  Broomhaugh House Riding Mill Northumberland NE...   NaN   NaN
#
#   person_ctry_code  cnt  chr_len  chr_len_label  ...  street   nr  \
# 0               JP    1       90              1  ...       0    0
# 1               JP    1       89              1  ...       0    0
# 2               JP    1       76              1  ...       0    0
# 3               JP    1       50              1  ...       0  2-3
# 4               GB    1       52              1  ...       0    0
#
#             area    postal                       city          region  \
# 0   Shizuoka-ken  424-0926   Shizuoka-shi, Shimizu-ku       Muramatsu
# 1        nagata-  100-6150                      Tokyo               0
# 2  Hinagahigashi         0              Yokkaichi-shi        510-0886
# 3     Chiyoda-ku  100-8310                      Tokyo               0
# 4              0  NE44 6EG                Riding Mill  Northumberland
#
#    country  unclear status label
# 0        0      NaN    NaN     0
# 1        0      NaN    NaN     0
# 2        0      NaN    NaN     0
# 3        0      NaN    NaN     0
# 4        0      NaN    NaN     0
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import LabelEncoder
l3 = LabelEncoder()

#make the columns as string and encode it to a numeric
country = l3.fit_transform(data['country'].astype(str))
city = l3.fit_transform(data['city'].astype(str))
region = l3.fit_transform(data['region'].astype(str))
postal = l3.fit_transform(data['postal'].astype(str))
area = l3.fit_transform(data['area'].astype(str))
street = l3.fit_transform(data['street'].astype(str))
co = l3.fit_transform(data['co'].astype(str))
building = l3.fit_transform(data['building'].astype(str))
nr = l3.fit_transform(data['nr'].astype(str))

# %%
#Replace originalcolumns witht the numeric columns
data['city'] = city
data['country'] = country
data['region'] = region
data['postal'] = postal
data['area'] = area
data['street'] = street
data['co'] = co
data['building'] = building
data['nr'] = nr

# %%
#Brief overview of first 50
data.head(50)
# Out:
#     person_id                                        person_name  \
# 0       89830                                      Hata, Yoshiki
# 1      118819    Sakamura, Ken, Intellectual Property Department
# 2      227620         Takeda, Yuji Yokkaichi Plant of Mitsubishi
# 3      300146   INOUE, Mitsuo, MITSUBISHI DENKI KABUSHIKI KAISHA
# 4      433394                   The Engineering Business Limited
# 5      455672                                KUMARAN, Govindaraj
# 6      516598                       Tosaka, Akio c/o Chiba Works
# 7      531009                                  Nagasawa, Keiichi
# 8      679171                                  Daizo Corporation
# 9     1286514                                        ARII, Teruo
# 10    1397519                                    Chang, Jae, Won
# 11    1434087                 Vinnolit Technologie GmbH & Co. KG
# 12    2706446                             Karius, Klaus Dietmark
# 13    2870551  Fujiwara, Takayoshi, c/o Intellectual Property...
# 14    3166235                                       Fumex, André
# 15    3174089                                    RIEBER, Roy, S.
# 16    3508769                        BOWLES FLUIDICS CORPORATION
# 17    3636484                                        SKOG, Terje
# 18    3811921                                     Madan, Sanjeev
# 19    5223007                                     Gumbel, Helmut
# 20    5223444                                   Legiec, Irene E.
# 21    5248897                                    Tsuji, Toshiaki
# 22    5297204                        Webcraft Technologies, Inc.
# 23    5304582                       Siegfried Aktiengesellschaft
# 24    5327396                          Sensor Technologies, Inc.
# 25    5330949                                       Hara, Yuichi
# 26    5343666                                    Espinosa, Frank
# 27    5350988                                      Gascon, Rheal
# 28    5357821                               Spademan, Richard G.
# 29    5371217                              Kelly, Jr., Thomas M.
# 30    5402680                              Venkatesh, Srilakshmi
# 31    5410707                                   Chien, Chen-Jung
# 32    5437029                                   Kakehi, Takamaro
# 33    5517990                                 Martin, Matthew R.
# 34    5545800                                     Jannard, James
# 35    5585872                             Cholestech Corporation
# 36    5626403                                     Dickson, LeRoy
# 37    5630911                                 Michel, Richard P.
# 38    5661137                                     Nakao, Yasushi
# 39    5678935                       Integrated Group Assets Inc.
# 40    5680169                                    Shemtov, Israel
# 41    5699851                                Zimmerman, Nancy J.
# 42    5705640                              Guzowshi, Pamela Lynn
# 43    5709927                                  Kuckes, Arthur F.
# 44    5712636                                      Kato, Akihiko
# 45    5748489                                        Kato, Naoki
# 46    5780223                                Yamaguchi, Kisaburo
# 47    5788985                                 Bailey, Kenneth S.
# 48    5794138                                   Bell, John Louis
# 49    5842127                                    Kini, M. Vittal
#
#                                        person_address  \
# 0   c/o Hitachi Appliances, Inc. 390 Muramatsu, Sh...
# 1   NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Naga...
# 2   Gas Chemical Company, Inc., 4-16-2, Hinagahiga...
# 3   2-3, Marunouchi 2-chome, Chiyoda-ku,Tokyo 100-...
# 4   Broomhaugh House Riding Mill,Northumberland NE...
# 5               1 Kimball Court, 504,Woburn, MA 01801
# 6   Kawasaki Steel Corporation 1, Kawasakicho Chuo...
# 7   Disco Corporation 13-11, Omori-Kita 2-chome Ot...
# 8   1-201, Fukuzaki 3-chome, Minato-ku Osaka-shi,O...
# 9   c/o Mitsui Chemicals, Inc. 1144, Togo,Mobara-s...
# 10  Mokryun Apt. 1241-1005 1091-1, Sanbon-Dong,Gun...
# 11                     Werk Gendorf,84508 Burgkirchen
# 12             Baltrumstrasse 12,D-4000 Düsseldorf 30
# 13  Kabushiki Kaisha Toshiba, 1-1 Shibaura 1-chome...
# 14        Le Bellevue Les Balmettes,F-74290 Talloires
# 15                 1302 Walnut Bend,Houston, TX 77042
# 16        P.O. Box 6300,Columbia, Maryland 21045-6300
# 17                             Solberg,N-3180 Nykirke
# 18              120 Vanita Drive,Coraopolis, PA 15108
# 19                                         Dannenfels
# 20                                    Mountainside,NJ
# 21                                               Kobe
# 22                                            Horsham
# 23                                           Zofingen
# 24                                         Pennsauken
# 25                                          Hiratsuka
# 26                                        Richmond,TX
# 27                                             Hanmer
# 28                                    Incline Village
# 29                                          Dedham,MA
# 30                                          Sunnyvale
# 31                                       Sunnyvale,CA
# 32                                         Nagaokakyo
# 33                                         Remsenburg
# 34                                       Eastsound,WA
# 35                                            Hayward
# 36                                     Morgan Hill,CA
# 37                                     Minneapolis,MN
# 38                                          Hiratsuka
# 39                                          Dallas,TX
# 40                                           Brooklyn
# 41                                            Clemson
# 42                                        Glenview,IL
# 43                                             Ithaca
# 44                                           Kanagawa
# 45                                            Kodaira
# 46                                           Hachioji
# 47                                    Longboat Key,FL
# 48                                       Annapolis,MD
# 49                                           Portland
#
#                                                  cln1  cln2  cln3  \
# 0   c/o Hitachi Appliances Inc. 390 Muramatsu Shim...   NaN   NaN
# 1   NTT DoCoMo Inc. Sanno Park Tower 11-1 Nagata- ...   NaN   NaN
# 2   Gas Chemical Company Inc. 4-16-2 Hinagahigashi...   NaN   NaN
# 3    2-3 Marunouchi 2-chome Chiyoda-ku Tokyo 100-8310   NaN   NaN
# 4   Broomhaugh House Riding Mill Northumberland NE...   NaN   NaN
# 5                 1 Kimball Court 504 Woburn MA 01801   NaN   NaN
# 6   Kawasaki Steel Corporation 1 Kawasakicho Chuo-...   NaN   NaN
# 7   Disco Corporation 13-11 Omori-Kita 2-chome Ota...   NaN   NaN
# 8   1-201 Fukuzaki 3-chome Minato-ku Osaka-shi Osa...   NaN   NaN
# 9   c/o Mitsui Chemicals Inc. 1144 Togo Mobara-shi...   NaN   NaN
# 10  Mokryun Apt. 1241-1005 1091-1 Sanbon-Dong Gunp...   NaN   NaN
# 11                     Werk Gendorf 84508 Burgkirchen   NaN   NaN
# 12             Baltrumstrasse 12 D-4000 Düsseldorf 30   NaN   NaN
# 13  Kabushiki Kaisha Toshiba 1-1 Shibaura 1-chome ...   NaN   NaN
# 14        Le Bellevue Les Balmettes F-74290 Talloires   NaN   NaN
# 15                  1302 Walnut Bend Houston TX 77042   NaN   NaN
# 16         P.O. Box 6300 Columbia Maryland 21045-6300   NaN   NaN
# 17                             Solberg N-3180 Nykirke   NaN   NaN
# 18               120 Vanita Drive Coraopolis PA 15108   NaN   NaN
# 19                                         Dannenfels   NaN   NaN
# 20                                    Mountainside NJ   NaN   NaN
# 21                                               Kobe   NaN   NaN
# 22                                            Horsham   NaN   NaN
# 23                                           Zofingen   NaN   NaN
# 24                                         Pennsauken   NaN   NaN
# 25                                          Hiratsuka   NaN   NaN
# 26                                        Richmond TX   NaN   NaN
# 27                                             Hanmer   NaN   NaN
# 28                                    Incline Village   NaN   NaN
# 29                                          Dedham MA   NaN   NaN
# 30                                          Sunnyvale   NaN   NaN
# 31                                       Sunnyvale CA   NaN   NaN
# 32                                         Nagaokakyo   NaN   NaN
# 33                                         Remsenburg   NaN   NaN
# 34                                       Eastsound WA   NaN   NaN
# 35                                            Hayward   NaN   NaN
# 36                                     Morgan Hill CA   NaN   NaN
# 37                                     Minneapolis MN   NaN   NaN
# 38                                          Hiratsuka   NaN   NaN
# 39                                          Dallas TX   NaN   NaN
# 40                                           Brooklyn   NaN   NaN
# 41                                            Clemson   NaN   NaN
# 42                                        Glenview IL   NaN   NaN
# 43                                             Ithaca   NaN   NaN
# 44                                           Kanagawa   NaN   NaN
# 45                                            Kodaira   NaN   NaN
# 46                                           Hachioji   NaN   NaN
# 47                                    Longboat Key FL   NaN   NaN
# 48                                       Annapolis MD   NaN   NaN
# 49                                           Portland   NaN   NaN
#
#    person_ctry_code  cnt  chr_len  chr_len_label  ...  street   nr  area  \
# 0                JP    1       90              1  ...      18    3   192
# 1                JP    1       89              1  ...      18    3   239
# 2                JP    1       76              1  ...      18    3    83
# 3                JP    1       50              1  ...      18   92    37
# 4                GB    1       52              1  ...      18    3     1
# 5                US    1       37              1  ...      18  189   244
# 6                JP    1       75              1  ...      18    4    94
# 7                JP    1       65              1  ...      18    3     1
# 8                JP    1       59              1  ...      18    6   167
# 9                JP    1       64              1  ...      18    3   213
# 10               KR    1       60              1  ...      18   23   181
# 11               DE    1       30              1  ...      18    3   225
# 12               DE    1       38              1  ...      18    3     1
# 13               JP    1       67              1  ...      18    3     1
# 14               FR    1       43              1  ...      18    3     1
# 15               US    1       34              1  ...      18   47   224
# 16               US    1       43              1  ...      18    3     1
# 17               NO    1       22              1  ...      18    3     1
# 18               US    1       37              1  ...     391   38    46
# 19               DE    1       10              1  ...      18    3    50
# 20               US    1       15              1  ...      18    3   137
# 21               JP    1        4              1  ...      18    3     1
# 22               US    1        7              1  ...      18    3     1
# 23               CH    1        8              1  ...      18    3     1
# 24               US    1       10              1  ...      18    3     1
# 25               JP    1        9              1  ...      18    3     1
# 26               US    1       11              1  ...      18    3     1
# 27               CA    1        6              1  ...      18    3     1
# 28               US    1       15              1  ...      18    3     1
# 29               US    1        9              1  ...      18    3     1
# 30               US    1        9              1  ...      18    3     1
# 31               US    1       12              1  ...      18    3     1
# 32               JP    1       10              1  ...      18    3     1
# 33               US    1       10              1  ...      18    3     1
# 34               US    1       12              1  ...      18    3     1
# 35               US    1        7              1  ...      18    3     1
# 36               US    1       14              1  ...      18    3     1
# 37               US    1       14              1  ...      18    3     1
# 38               JP    1        9              1  ...      18    3     1
# 39               US    1        9              1  ...      18    3     1
# 40               US    1        8              1  ...      18    3    24
# 41               US    1        7              1  ...      18    3     1
# 42               US    1       11              1  ...      18    3     1
# 43               US    1        6              1  ...      18    3     1
# 44               JP    1        8              1  ...      18    3     1
# 45               JP    1        7              1  ...      18    3     1
# 46               JP    1        8              1  ...      18    3     1
# 47               US    1       15              1  ...      18    3     1
# 48               US    1       12              1  ...      18    3     1
# 49               US    1        8              1  ...      18    3     1
#
#     postal  city  region  country                      unclear status  label
# 0      151     1      91        1                          NaN    NaN      0
# 1       30   606       3        1                          NaN    NaN      0
# 2        5   668       4        1                          NaN    NaN      0
# 3       32   606       3        1                          NaN    NaN      0
# 4      405   506     107        1                          NaN    NaN      0
# 5       11     2      73        1                          NaN    NaN      0
# 6        1   108       3        1                          NaN    NaN      0
# 7        5     2       3        1                          NaN    NaN      0
# 8      201   453       3        1  Fukuzaki 3-chome, Minato-ku    NaN      0
# 9      118   388      32        1                          NaN    NaN      0
# 10       5   219      47        1                          NaN    NaN      0
# 11     279    80       3        1                          NaN    NaN      0
# 12       5     2       3        1                          NaN    NaN      0
# 13       5     2       3        1                          NaN    NaN      0
# 14     363   592       3        1                          NaN    NaN      0
# 15     266   259     142        1                          NaN    NaN      0
# 16      92   123      84        1                          NaN    NaN      0
# 17     402   440       3        1                          NaN    NaN      0
# 18      68     2     118        1                          NaN    NaN      0
# 19       5     2       3        1                          NaN    NaN      0
# 20       5     2      96        1                          NaN    NaN      0
# 21       5   308       3        1                          NaN    NaN      0
# 22       5   257       3        1                          NaN    NaN      0
# 23       5   682       3        1                          NaN    NaN      0
# 24       5   472       3        1                          NaN    NaN      0
# 25       5   250       3        1                          NaN    NaN      0
# 26       5   504     142        1                          NaN    NaN      0
# 27       5   231       3        1                          NaN    NaN      0
# 28       5   273       3        1                          NaN    NaN      0
# 29       5   137      73        1                          NaN    NaN      0
# 30       5   573       3        1                          NaN    NaN      0
# 31       5   573      24        1                          NaN    NaN      0
# 32       5   407       3        1                          NaN    NaN      0
# 33       5   501       3        1                          NaN    NaN      0
# 34       5   155     155        1                          NaN    NaN      0
# 35       5   237       3        1                          NaN    NaN      0
# 36       5   394      24        1                          NaN    NaN      0
# 37       5   386      78        1                          NaN    NaN      0
# 38       5   250       3        1                          NaN    NaN      0
# 39       5   135     142        1                          NaN    NaN      0
# 40       5     2       3        1                          NaN    NaN      0
# 41       5   118       3        1                          NaN    NaN      0
# 42       5   206      57        1                          NaN    NaN      0
# 43       5   276       3        1                          NaN    NaN      0
# 44       5     2      62        1                          NaN    NaN      0
# 45       5   311       3        1                          NaN    NaN      0
# 46       5   225       3        1                          NaN    NaN      0
# 47       5   346      38        1                          NaN    NaN      0
# 48       5    18      74        1                          NaN    NaN      0
# 49       5   483       3        1                          NaN    NaN      0
#
# [50 rows x 31 columns]

# %%
#Detailed overview
data.describe()
# Out:
#           person_id  cln2  cln3    cnt     chr_len  chr_len_label     nbr_tok  \
# count  9.990000e+02   0.0   0.0  999.0  999.000000          999.0  999.000000
# mean   2.070643e+07   NaN   NaN    1.0   32.092092            1.0    4.703704
# std    2.175683e+07   NaN   NaN    0.0   26.633592            0.0    3.758530
# min    3.540000e+03   NaN   NaN    1.0    2.000000            1.0    1.000000
# 25%    3.854371e+06   NaN   NaN    1.0   10.000000            1.0    1.000000
# 50%    9.143170e+06   NaN   NaN    1.0   29.000000            1.0    4.000000
# 75%    4.806491e+07   NaN   NaN    1.0   47.000000            1.0    7.000000
# max    6.971232e+07   NaN   NaN    1.0  164.000000            1.0   20.000000
#
#        nbr_tok_num  has_tok_3digits  nbr_digits  ...    building      street  \
# count          0.0              0.0         0.0  ...  999.000000  999.000000
# mean           NaN              NaN         NaN  ...    8.287287  117.695696
# std            NaN              NaN         NaN  ...   12.921086  140.093289
# min            NaN              NaN         NaN  ...    0.000000    0.000000
# 25%            NaN              NaN         NaN  ...    5.000000   18.000000
# 50%            NaN              NaN         NaN  ...    5.000000   18.000000
# 75%            NaN              NaN         NaN  ...    5.000000  216.500000
# max            NaN              NaN         NaN  ...   85.000000  461.000000
#
#                nr        area      postal        city      region     country  \
# count  999.000000  999.000000  999.000000  999.000000  999.000000  999.000000
# mean    49.288288   32.511512   92.729730  311.948949   31.118118    1.436436
# std     75.903938   64.142186  127.941906  221.292538   46.385399    2.545323
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    1.000000    5.000000  100.500000    3.000000    1.000000
# 50%      3.000000    1.000000    5.000000  315.000000    3.000000    1.000000
# 75%     81.000000   12.500000  174.500000  519.500000   48.000000    1.000000
# max    266.000000  245.000000  418.000000  687.000000  165.000000   23.000000
#
#        status       label
# count     0.0  999.000000
# mean      NaN    0.470470
# std       NaN    0.499377
# min       NaN    0.000000
# 25%       NaN    0.000000
# 50%       NaN    0.000000
# 75%       NaN    1.000000
# max       NaN    1.000000
#
# [8 rows x 25 columns]

# %%
#Just checkking how many are "right" and "false"
correct_address_map = {1.0: 1, 0.0: 0}
data['label'] = data['label'].map(correct_address_map)
correct_address_true_count = len(data.loc[data['label'] == True])
correct_address_false_count = len(data.loc[data['label'] == False])
(correct_address_true_count,correct_address_false_count)
# Out:
# (470, 529)

# %%
#renaming columns
from sklearn.model_selection import train_test_split
feature_columns = ['co', 'building', 'street','nr','area','postal','city','region','country']
predicted_class = ['label']

# %%
#renaming columns
X = data[feature_columns].values
Y = data[predicted_class].values


#renaming columns
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3) # 70% training and 30% test

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)
# Out:
# C:\Users\DePau\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9566666666666667
